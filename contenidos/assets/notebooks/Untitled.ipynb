# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.linspace(0,4)
y1 = 1
y2 = np.log2(x)
y3 = np.sqrt(x)
y4 = x
y5= x**2
y6= x ** 3
y7 = np.exp(x)
# Out:
# /tmp/ipykernel_8719/1187986727.py:3: RuntimeWarning: divide by zero encountered in log2
#   y2 = np.log2(x)

# %%
#plt.plot(x, y1, label = 'f(x)')
plt.plot(x, y2, label = 'log(x)')
plt.plot(x, y3, label = 'x^2')
plt.plot(x, y4)
plt.plot(x, y5)
plt.plot(x, y6)
plt.legend()
